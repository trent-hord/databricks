# %%
print("Hello World!")

# %%
# %sql
SELECT "Hello world from SQLI"

# %% [markdown]
# # TITLE 1
# ## TITLE 2
#
# test with *intalics* "*"
# **BOLD text**

# %%
# %run ./Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls('/databricks-datasets')
print(files)

# %%
display(files)
